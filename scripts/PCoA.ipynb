# %% [markdown]
# <h1 style="text-align:Center; color:orange;">- iPython Notebook -</h1>

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>
# <h4 style="text-align:center; color:blue;">Andrew W. Brooks</h4>
# <h4 style="text-align:center; color:blue;">Vanderbilt Genetics Institute</h4>
# <h4 style="text-align:center; color:blue;">andrew.w.brooks(at)vanderbilt.edu</h4>
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %%
######################################################
### LOAD USEFUL TOOLS ################################
### MODULES:
#%matplotlib inline
import sys
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
#################################################
################# SEARCH ########################    
import glob
### SEARCH FUNCTION ### regex search files (returns list of files matching regex expression)
def search(searchStr):
    return glob.glob(searchStr)

### SEARCH FUNCTION ### search and list all files in directory
def search_all(searchPath='./', printOut = True):
    if printOut == True: print_enumerate(search(searchPath + '*'))
    return search(searchPath + '*')

#################################################
################## PRINT ########################
### PRINT FUNCTION ### print a list lead by numbers
def print_enumerate(inList, leadStr="   ", sepStr=". "):
    for idx, idi in enumerate(inList): print leadStr+str(idx)+sepStr+idi
        
#################################################
################## COLOR ########################
###  COLOR FUNCTION ### return iterator of 8 basic colors
def get_color8():
    colorList = ['r','b','g','y','c','k','m','w']
    for i in colorList: yield i

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1 style="text-align:Center; color:orange;">- USER INPUT (CHOOSE DATASET)-</h1>

# %%
##### SELECT ONE #####

### DROSOPHILA ###
datasetIn = "../data/drosophila/5_6_jackknifed_beta_diversity_514/bray_curtis/"
mapPath = "../data/drosophila/drosophila_map.txt"
mapColInterest = 'Treatment'

# %%
### HOMINID ###
datasetIn = "../data/hominid/5_6_jackknifed_beta_diversity_14490/bray_curtis/" 
mapPath = "../data/hominid/map.txt"
mapColInterest = "phylo"

# %%
### META ###
datasetIn = "../data/meta/5_6_jackknifed_beta_diversity_163/bray_curtis/" 
mapPath = "../data/meta/all_maps.txt"
mapColInterest = "Experiment"

# %%
### MOSQUITO ###
datasetIn = "../data/mosquito/5_6_jackknifed_beta_diversity_833/bray_curtis/" 
mapPath = "../data/mosquito/mosquito_map.txt"
mapColInterest = "Treatment"

# %%
### NASONIA ###
datasetIn = "../data/nasonia/5_6_jackknifed_beta_diversity_2069/bray_curtis/" 
mapPath = "../data/nasonia/nasonia_map.txt"
mapColInterest = "Treatment"

# %%
### PEROMYSCUS ###
datasetIn = "../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/" 
mapPath = "../data/peromyscus/map.txt"
mapColInterest = "Treatment"

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %% [markdown]
# <h1 style="text-align:Center; color:orange;">- AUTOMATED 3D PCOA PLOT CONSTRUCTION -</h1>

# %%
##### INPUT THE MAPPING FILE #####
mapdf = pd.read_csv(mapPath, sep='\t', index_col=0, skiprows=None, verbose=False)
mapdf
# Out:
#           BarcodeSequence LinkerPrimerSequence Treatment phylo  Description
# #SampleID
# PIS1             AAAAAAAA     AGAGTTTGATCMTGGC        IS    IS            3
# PIS2             AAAGTGAA     AGAGTTTGATCMTGGC        IS    IS            3
# PIS4             AAGGGAAA     AGAGTTTGATCMTGGC        IS    IS            3
# PIS5             ACACGACC     AGAGTTTGATCMTGGC        IS    IS            3
# PIS7             ACATCGCC     AGAGTTTGATCMTGGC        IS    IS            3
# PIS8             ACGTAACC     AGAGTTTGATCMTGGC        IS    IS            3
# PIS9             AGAGTAGG     AGAGTTTGATCMTGGC        IS    IS            3
# PIS10            AGAAAGGG     AGAGTTTGATCMTGGC        IS    IS            3
# PIS11            AGGACAGG     AGAGTTTGATCMTGGC        IS    IS            3
# PIS12            ATATCATT     AGAGTTTGATCMTGGC        IS    IS            3
# PIS14            ATACGGTT     AGAGTTTGATCMTGGC        IS    IS            3
# PIS15            ATGCTATT     AGAGTTTGATCMTGGC        IS    IS            3
# PEP16            CCCCTAAA     AGAGTTTGATCMTGGC        EP    EP            3
# PEP17            CCCTAGAA     AGAGTTTGATCMTGGC        EP    EP            3
# PEP18            CCTTCAAA     AGAGTTTGATCMTGGC        EP    EP            3
# PEP20            CACACACC     AGAGTTTGATCMTGGC        EP    EP            3
# PEP21            CACGGGCC     AGAGTTTGATCMTGGC        EP    EP            3
# PEP22            CATGTACC     AGAGTTTGATCMTGGC        EP    EP            3
# PEP23            CTCTAAGG     AGAGTTTGATCMTGGC        EP    EP            3
# PEP24            CTCCTGGG     AGAGTTTGATCMTGGC        EP    EP            3
# PEP25            CTTCGAGG     AGAGTTTGATCMTGGC        EP    EP            3
# PEP26            CGCGGATT     AGAGTTTGATCMTGGC        EP    EP            3
# PEP27            CGCACGTT     AGAGTTTGATCMTGGC        EP    EP            3
# PEP28            CGTAAATT     AGAGTTTGATCMTGGC        EP    EP            3
# PEP29            GGGGCAAA     AGAGTTTGATCMTGGC        EP    EP            3
# PEP30            GGGAGGAA     AGAGTTTGATCMTGGC        EP    EP            3
# PAM31            GGACCCAA     AGAGTTTGATCMTGGC        AM    AM            2
# PAM32            GTGTTACC     AGAGTTTGATCMTGGC        AM    AM            2
# PAM33            GTGCAGCC     AGAGTTTGATCMTGGC        AM    AM            2
# PAM34            GTAATCCC     AGAGTTTGATCMTGGC        AM    AM            2
# ...                   ...                  ...       ...   ...          ...
# PBW49            TCTCCAGG     AGAGTTTGATCMTGGC        BW    BW            1
# PBW50            TCTTGGGG     AGAGTTTGATCMTGGC        BW    BW            1
# PBW51            TCCGCCGG     AGAGTTTGATCMTGGC        BW    BW            1
# PBW52            TATATATT     AGAGTTTGATCMTGGC        BW    BW            1
# PBW53            TATGAGTT     AGAGTTTGATCMTGGC        BW    BW            1
# PBW54            TACTTCTT     AGAGTTTGATCMTGGC        BW    BW            1
# PBW55            AAACGCAA     AGAGTTTGATCMTGGC        BW    BW            1
# PBW56            AAATCTAA     AGAGTTTGATCMTGGC        BW    BW            1
# PBW58            AAGACGAA     AGAGTTTGATCMTGGC        BW    BW            1
# PBW59            ACAAACCC     AGAGTTTGATCMTGGC        BW    BW            1
# PBW60            ACAGTTCC     AGAGTTTGATCMTGGC        BW    BW            1
# PPO64            ACGCTGCC     AGAGTTTGATCMTGGC        PO    PO            1
# PPO66            AGATCCGG     AGAGTTTGATCMTGGC        PO    PO            1
# PPO67            AGACGTGG     AGAGTTTGATCMTGGC        PO    PO            1
# PPO68            AGGGGGGG     AGAGTTTGATCMTGGC        PO    PO            1
# PPO69            ATAGTCTT     AGAGTTTGATCMTGGC        PO    PO            1
# PPO72            ATAAATTT     AGAGTTTGATCMTGGC        PO    PO            1
# PPO75            ATGTAGTT     AGAGTTTGATCMTGGC        PO    PO            1
# PLL76            CCCACCAA     AGAGTTTGATCMTGGC        LL    LL            2
# PLL77            CCCGGTAA     AGAGTTTGATCMTGGC        LL    LL            2
# PLL79            CCTCGGAA     AGAGTTTGATCMTGGC        LL    LL            2
# PLL80            CACCTCCC     AGAGTTTGATCMTGGC        LL    LL            2
# PLL81            CACTATCC     AGAGTTTGATCMTGGC        LL    LL            2
# PLL83            CATAAGCC     AGAGTTTGATCMTGGC        LL    LL            2
# PLL84            CTCGGCGG     AGAGTTTGATCMTGGC        LL    LL            2
# PLL85            CTCACTGG     AGAGTTTGATCMTGGC        LL    LL            2
# PLL86            CTTTCGGG     AGAGTTTGATCMTGGC        LL    LL            2
# PLL88            CGCTACTT     AGAGTTTGATCMTGGC        LL    LL            2
# PLL89            CGCCTTTT     AGAGTTTGATCMTGGC        LL    LL            2
# PLL90            CGTGTGTT     AGAGTTTGATCMTGGC        LL    LL            2
#
# [72 rows x 5 columns]

# %%
##### SELECT DATASET FILES #####
### AFTER PICKING A DATASET ENTER THIS TO MAKE SURE PCOA FILES ARE FOUND CORRECTLY ###
pcoaFiles = search_all(datasetIn + 'pcoa/', printOut=True)
print_enumerate(pcoaFiles)
# Out:
#    0. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_0.txt
#    1. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_1.txt
#    2. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_10.txt
#    3. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_11.txt
#    4. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_12.txt
#    5. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_13.txt
#    6. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_14.txt
#    7. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_15.txt
#    8. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_16.txt
#    9. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_17.txt
#    10. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_18.txt
#    11. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_19.txt
#    12. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_2.txt
#    13. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_20.txt
#    14. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_21.txt
#    15. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_22.txt
#    16. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_23.txt
#    17. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_24.txt
#    18. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_25.txt
#    19. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_26.txt
#    20. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_27.txt
#    21. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_28.txt
#    22. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_29.txt
#    23. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_3.txt
#    24. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_30.txt
#    25. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_31.txt
#    26. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_32.txt
#    27. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_33.txt
#    28. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_34.txt
#    29. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_35.txt
#    30. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_36.txt
#    31. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_37.txt
#    32. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_38.txt
#    33. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_39.txt
#    34. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_4.txt
#    35. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_40.txt
#    36. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_41.txt
#    37. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_42.txt
#    38. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_43.txt
#    39. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_44.txt
#    40. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_45.txt
#    41. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_46.txt
#    42. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_47.txt
#    43. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_48.txt
#    44. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_49.txt
#    45. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_5.txt
#    46. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_50.txt
#    47. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_51.txt
#    48. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_52.txt
#    49. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_53.txt
#    50. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_54.txt
#    51. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_55.txt
#    52. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_56.txt
#    53. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_57.txt
#    54. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_58.txt
#    55. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_59.txt
#    56. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_6.txt
#    57. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_60.txt
#    58. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_61.txt
#    59. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_62.txt
#    60. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_63.txt
#    61. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_64.txt
#    62. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_65.txt
#    63. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_66.txt
#    64. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_67.txt
#    65. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_68.txt
#    66. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_69.txt
#    67. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_7.txt
#    68. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_70.txt
#    69. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_71.txt
#    70. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_72.txt
#    71. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_73.txt
#    72. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_74.txt
#    73. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_75.txt
#    74. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_76.txt
#    75. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_77.txt
#    76. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_78.txt
#    77. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_79.txt
#    78. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_8.txt
#    79. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_80.txt
#    80. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_81.txt
#    81. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_82.txt
#    82. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_83.txt
#    83. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_84.txt
#    84. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_85.txt
#    85. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_86.txt
#    86. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_87.txt
#    87. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_88.txt
#    88. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_89.txt
#    89. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_9.txt
#    90. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_90.txt
#    91. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_91.txt
#    92. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_92.txt
#    93. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_93.txt
#    94. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_94.txt
#    95. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_95.txt
#    96. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_96.txt
#    97. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_97.txt
#    98. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_98.txt
#    99. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_99.txt
#    0. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_0.txt
#    1. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_1.txt
#    2. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_10.txt
#    3. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_11.txt
#    4. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_12.txt
#    5. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_13.txt
#    6. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_14.txt
#    7. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_15.txt
#    8. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_16.txt
#    9. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_17.txt
#    10. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_18.txt
#    11. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_19.txt
#    12. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_2.txt
#    13. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_20.txt
#    14. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_21.txt
#    15. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_22.txt
#    16. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_23.txt
#    17. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_24.txt
#    18. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_25.txt
#    19. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_26.txt
#    20. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_27.txt
#    21. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_28.txt
#    22. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_29.txt
#    23. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_3.txt
#    24. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_30.txt
#    25. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_31.txt
#    26. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_32.txt
#    27. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_33.txt
#    28. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_34.txt
#    29. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_35.txt
#    30. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_36.txt
#    31. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_37.txt
#    32. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_38.txt
#    33. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_39.txt
#    34. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_4.txt
#    35. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_40.txt
#    36. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_41.txt
#    37. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_42.txt
#    38. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_43.txt
#    39. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_44.txt
#    40. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_45.txt
#    41. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_46.txt
#    42. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_47.txt
#    43. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_48.txt
#    44. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_49.txt
#    45. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_5.txt
#    46. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_50.txt
#    47. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_51.txt
#    48. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_52.txt
#    49. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_53.txt
#    50. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_54.txt
#    51. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_55.txt
#    52. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_56.txt
#    53. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_57.txt
#    54. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_58.txt
#    55. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_59.txt
#    56. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_6.txt
#    57. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_60.txt
#    58. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_61.txt
#    59. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_62.txt
#    60. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_63.txt
#    61. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_64.txt
#    62. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_65.txt
#    63. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_66.txt
#    64. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_67.txt
#    65. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_68.txt
#    66. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_69.txt
#    67. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_7.txt
#    68. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_70.txt
#    69. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_71.txt
#    70. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_72.txt
#    71. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_73.txt
#    72. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_74.txt
#    73. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_75.txt
#    74. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_76.txt
#    75. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_77.txt
#    76. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_78.txt
#    77. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_79.txt
#    78. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_8.txt
#    79. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_80.txt
#    80. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_81.txt
#    81. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_82.txt
#    82. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_83.txt
#    83. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_84.txt
#    84. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_85.txt
#    85. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_86.txt
#    86. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_87.txt
#    87. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_88.txt
#    88. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_89.txt
#    89. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_9.txt
#    90. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_90.txt
#    91. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_91.txt
#    92. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_92.txt
#    93. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_93.txt
#    94. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_94.txt
#    95. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_95.txt
#    96. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_96.txt
#    97. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_97.txt
#    98. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_98.txt
#    99. ../data/peromyscus/5_6_jackknifed_beta_diversity_165/bray_curtis/pcoa/pcoa_bray_curtis_rarefaction_165_99.txt

# %%
##### INPUT THE PCOA FILES #####
pandasDFs = []
for pcoaFile in pcoaFiles:
    pandasDFs.append(pd.read_csv(pcoaFiles[0], sep='\t', index_col=None, skiprows=None, verbose=False))

# %%
##### AVERAGE THE 100 RAREFIED PCOA RESULTS #####
pandasPCoAs = []
pandasEigens = []

pPCoA = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][0:(len(pandasDFs[0])-2)])
pEigens = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][(len(pandasDFs[0])-2):])
pPCoA.fillna(0, inplace=True)
pEigens.fillna(0, inplace=True)

for idx, i in enumerate(pandasDFs):
    #print idx
    x = pandasDFs[idx]
    x1 = pd.DataFrame(columns=[0,1,2], index=x['pc vector number'][0:(len(x)-2)])
    x1[0] = x['1'][0:(len(x)-2)].values
    x1[1] = x['2'][0:(len(x)-2)].values
    x1[2] = x['3'][0:(len(x)-2)].values
    x2 = pd.DataFrame(columns=[0,1,2], index=x['pc vector number'][(len(x)-2):])
    x2[0] = x['1'][(len(x)-2):].values
    x2[1] = x['2'][(len(x)-2):].values
    x2[2] = x['3'][(len(x)-2):].values
    #print x1.head()
    #print x2.head()
    pandasPCoAs.append(x1)
    pandasEigens.append(x2)
    pPCoA = pPCoA.add(x1)
    pEigens = pEigens.add(x2)
#print pPCoA
#print pEigens
pPCoA = pPCoA.divide(len(pandasDFs))
pEigens = pEigens.divide(len(pandasDFs))
print pEigens
print pPCoA
# Out:
#                               0         1         2
# pc vector number
# eigvals                2.266812  1.204265  0.991712
# % variation explained  8.901560  4.729037  3.894362
#                          0         1         2
# pc vector number
# PAM31             0.364453 -0.120127 -0.033448
# PAM32             0.342888 -0.207413 -0.071527
# PAM33             0.391353 -0.130695 -0.071091
# PAM35             0.259782  0.026909 -0.033263
# PAM36             0.292236 -0.051155  0.010531
# PAM37             0.382330 -0.137370 -0.024752
# PAM39             0.417093 -0.151871 -0.034266
# PAM40             0.293304 -0.071505  0.042624
# PAM41             0.365171 -0.178413 -0.048729
# PAM42             0.335134 -0.046961  0.005715
# PAM43             0.277389 -0.068445  0.021997
# PAM44             0.049607  0.008540 -0.022931
# PAM45             0.235780 -0.076060 -0.055355
# PBW46            -0.167809 -0.203564  0.081254
# PBW47            -0.128903  0.020212  0.017624
# PBW49            -0.210416 -0.263220  0.035310
# PBW50            -0.137102 -0.120470  0.055069
# PBW51            -0.217116 -0.210422  0.099591
# PBW52            -0.188772 -0.238901  0.116539
# PBW53            -0.204340 -0.273193  0.122793
# PBW54            -0.220673 -0.206316  0.105543
# PBW55            -0.186242 -0.193810  0.044682
# PBW56            -0.142837 -0.005250 -0.043297
# PBW58            -0.006927  0.014924 -0.017313
# PBW59            -0.116198  0.005465 -0.015298
# PBW60            -0.156271  0.043521  0.001544
# PEP16            -0.129171  0.046357 -0.247211
# PEP18            -0.116915  0.070166 -0.315866
# PEP21            -0.111470  0.126144 -0.270892
# PEP23            -0.049407  0.102854 -0.292504
# PEP24            -0.098088  0.165745 -0.174086
# PEP26            -0.065103  0.061404 -0.197029
# PEP27            -0.111207  0.116696 -0.254373
# PEP28            -0.061719  0.116921 -0.178428
# PEP29            -0.080427  0.143267 -0.126434
# PEP30            -0.143626  0.097352 -0.216931
# PIS1              0.167585  0.190461  0.113847
# PIS2             -0.017293  0.141298  0.117884
# PIS4              0.034525  0.114638  0.125072
# PIS5             -0.002413  0.272469  0.198749
# PIS7              0.014748  0.211065  0.129043
# PIS9              0.134371  0.191318  0.093729
# PIS10             0.115794  0.280973  0.195226
# PIS11             0.226879  0.105500  0.124501
# PIS14             0.096279  0.284525  0.135691
# PIS15             0.101226  0.278378  0.129855
# PLL76            -0.146145  0.095539  0.193584
# PLL77            -0.152054  0.050343  0.257585
# PLL79            -0.158295  0.002308  0.115933
# PLL80            -0.185057 -0.017364  0.030969
# PLL83            -0.161273  0.027918  0.034303
# PLL88            -0.120135  0.058253  0.059602
# PLL89            -0.186251 -0.104531  0.014560
# PLL90            -0.120275 -0.055677  0.129389
# PPO64             0.118453 -0.071319 -0.035760
# PPO66            -0.108920  0.000380 -0.092572
# PPO67            -0.147709 -0.104316 -0.056388
# PPO69            -0.107903 -0.038335 -0.065167
# PPO72            -0.184266 -0.063065  0.041358
# PPO75            -0.167650 -0.062081 -0.006782

# %%
##### MAKE AND DISPLAY 3D PCOA PLOT #####
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111, projection='3d')
colorNext = get_color8()
colorCombo = {}
locCombo = {}

# For each sample
for i in pPCoA.index:
    # Get map group (species or experiment)
    mdVal = mapdf.loc[i][mapColInterest]
    # If that category is already created
    if mdVal in colorCombo.keys():
        # Get it's associated color
        curColor = colorCombo[mdVal]
        # Store the location values
        locCombo[mdVal].loc[i] = [pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2]]
    else:
        # Get next color
        curColor = colorNext.next()
        # Store it's associated color
        colorCombo[mdVal] = curColor
        # Create DF for positions of that category
        locCombo[mdVal] = pd.DataFrame(columns=[0,1,2])
        # Store the location values
        locCombo[mdVal].loc[i] = [pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2]]

        
    ax.scatter(pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2], c=str(curColor), marker='o')


for i in locCombo.keys():
    print i + " Group Centers"
    print "Group Color: " + colorCombo[i]
    ax0Mean = np.mean(locCombo[i][0])
    ax1Mean = np.mean(locCombo[i][1])
    ax2Mean = np.mean(locCombo[i][2])
    print ax0Mean, ax1Mean, ax2Mean
    ax.plot([ax0Mean, ax0Mean], [ax1Mean, ax1Mean], [-0.6, ax2Mean], '--', linewidth=2, color='k', alpha=1)
    ax.scatter(ax0Mean, ax1Mean, ax2Mean, s=200, c=str(colorCombo[i]), marker=(5, 1))

ax.set_xlabel('PCoA 1 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',0])))+'%')
ax.set_ylabel('PCoA 2 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',1])))+'%')
ax.set_zlabel('PCoA 3 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',2])))+'%')

ax.set_xlim()
ax.set_zlim()

plt.show()
# Out:
# IS Group Centers
# Group Color: y
# 0.0871699947193 0.207062522456 0.136359552891
# AM Group Centers
# Group Color: r
# 0.308193894151 -0.0926587807436 -0.0241919451467
# EP Group Centers
# Group Color: g
# -0.0967132959034 0.104690671468 -0.227375530446
# BW Group Centers
# Group Color: b
# -0.160277362478 -0.125463199526 0.0464647394744
# PO Group Centers
# Group Color: k
# -0.099665955163 -0.0564559719145 -0.0358852758193
# LL Group Centers
# Group Color: c
# -0.153685771117 0.00709870446891 0.104490638026
