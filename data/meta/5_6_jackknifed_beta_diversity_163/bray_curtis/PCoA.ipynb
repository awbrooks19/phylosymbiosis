# %% [markdown]
# <h1 style="text-align:Center; color:orange;">- iPython Notebook -</h1>

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>
# <h4 style="text-align:center; color:blue;">Andrew W. Brooks</h4>
# <h4 style="text-align:center; color:blue;">Vanderbilt Genetics Institute</h4>
# <h4 style="text-align:center; color:blue;">andrew.w.brooks(at)vanderbilt.edu</h4>
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %%
######################################################
### LOAD USEFUL TOOLS ################################
### MODULES:
#%matplotlib inline
import sys
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
### SCRIPTS:
sys.path.append("/Users/brooks/brooks_utilities/scripts/")
import python_utilities as p
#import mpld3
#mpld3.enable_notebook()

# %%
#################################################
################# SEARCH ########################    
import glob
### SEARCH FUNCTION ### regex search files (returns list of files matching regex expression)
def search(searchStr):
    return glob.glob(searchStr)

### SEARCH FUNCTION ### search and list all files in directory
def search_all(searchPath='./', printOut = True):
    if printOut == True: print_enumerate(search(searchPath + '*'))
    return search(searchPath + '*')

#################################################
################## PRINT ########################
### PRINT FUNCTION ### print a list lead by numbers
def print_enumerate(inList, leadStr="   ", sepStr=". "):
    for idx, idi in enumerate(inList): print leadStr+str(idx)+sepStr+idi

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %%
#search_all()
pcoaFiles = search_all('pcoa/', printOut=False)

# %%
pandasDFs = []
for pcoaFile in pcoaFiles:
    pandasDFs.append(pd.read_csv(pcoaFiles[0], sep='\t', index_col=None, skiprows=None, verbose=False))

# %%
pandasPCoAs = []
pandasEigens = []

pPCoA = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][0:(len(pandasDFs[0])-2)])
pEigens = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][(len(pandasDFs[0])-2):])
pPCoA.fillna(0, inplace=True)
pEigens.fillna(0, inplace=True)

#print pPCoA
#print pEigens

for idx, i in enumerate(pandasDFs):
    #print idx
    x = pandasDFs[idx]
    x1 = pd.DataFrame(columns=[0,1,2], index=x['pc vector number'][0:(len(x)-2)])
    x1[0] = x['1'][0:(len(x)-2)].values
    x1[1] = x['2'][0:(len(x)-2)].values
    x1[2] = x['3'][0:(len(x)-2)].values
    x2 = pd.DataFrame(columns=[0,1,2], index=x['pc vector number'][(len(x)-2):])
    x2[0] = x['1'][(len(x)-2):].values
    x2[1] = x['2'][(len(x)-2):].values
    x2[2] = x['3'][(len(x)-2):].values
    #print x1.head()
    #print x2.head()
    pandasPCoAs.append(x1)
    pandasEigens.append(x2)
    pPCoA = pPCoA.add(x1)
    pEigens = pEigens.add(x2)
#print pPCoA
#print pEigens
pPCoA = pPCoA.divide(len(pandasDFs))
pEigens = pEigens.divide(len(pandasDFs))
print pEigens
print pPCoA
# Out:
#                                0          1         2
# pc vector number
# eigvals                17.401189  12.218687  7.527803
# % variation explained  12.571949   8.827714  5.438660
#                          0         1         2
# pc vector number
# CA7              -0.379879 -0.198229  0.079852
# CA8              -0.394336 -0.223191  0.090020
# CB7              -0.345289 -0.149192  0.027246
# CB8              -0.373327 -0.185628  0.060754
# CC7              -0.246338 -0.087707  0.009472
# CC8              -0.278814 -0.164434  0.049154
# CD7              -0.408605 -0.223538  0.096608
# CD8              -0.370583 -0.203794  0.088108
# CE7              -0.385315 -0.195787  0.073701
# CE8              -0.393850 -0.214138  0.080987
# CF7              -0.242518 -0.105515  0.026935
# CF8              -0.306386 -0.127922  0.028450
# CG7              -0.368198 -0.167619  0.041197
# CG8              -0.327326 -0.137745  0.020865
# CH7              -0.417075 -0.215499  0.076716
# CH8              -0.414852 -0.219461  0.091725
# CA1              -0.087568  0.058070 -0.110541
# CA2              -0.117603  0.033959 -0.095878
# CB1              -0.121205  0.028663 -0.085597
# CB2              -0.105415  0.047759 -0.104079
# CC1              -0.293502 -0.189189  0.065815
# CC2              -0.229306 -0.095921  0.008883
# CD1              -0.070346  0.065378 -0.100481
# CD2              -0.113255  0.034344 -0.083866
# CE1              -0.194154 -0.073187 -0.009373
# CE2              -0.125690 -0.011416 -0.039603
# CF1              -0.181087 -0.033275 -0.060995
# CF2              -0.198656 -0.040572 -0.039881
# CG1              -0.239268 -0.064611 -0.033627
# CG2              -0.211245 -0.038982 -0.048825
# ...                    ...       ...       ...
# PEP24             0.003347  0.160724 -0.238820
# PEP26             0.002997  0.145281 -0.207579
# PEP27             0.002842  0.148912 -0.208519
# PEP28             0.003161  0.150969 -0.214621
# PEP29             0.004086  0.159927 -0.238279
# PEP30             0.003528  0.150301 -0.213669
# PIS1              0.003729  0.155745 -0.230140
# PIS2              0.003287  0.149165 -0.211857
# PIS4              0.004807  0.154862 -0.229479
# PIS5              0.002907  0.154623 -0.223370
# PIS7              0.002636  0.145671 -0.200987
# PIS9              0.003910  0.159974 -0.239705
# PIS10             0.003510  0.158525 -0.234670
# PIS11             0.003941  0.173775 -0.273833
# PIS14             0.003906  0.153255 -0.222724
# PIS15             0.003765  0.178160 -0.282518
# PLL76             0.003589  0.163619 -0.246136
# PLL77             0.002910  0.156461 -0.227855
# PLL79             0.003103  0.155735 -0.225290
# PLL80             0.003036  0.150866 -0.213743
# PLL83             0.003151  0.144148 -0.197993
# PLL88             0.003395  0.151437 -0.216855
# PLL89             0.004427  0.167080 -0.255511
# PLL90             0.002631  0.145826 -0.201143
# PPO64             0.003943  0.165664 -0.253603
# PPO66             0.002444  0.133780 -0.171238
# PPO67             0.002664  0.150721 -0.212483
# PPO69             0.003017  0.141977 -0.192490
# PPO72             0.003633  0.156579 -0.228944
# PPO75             0.002905  0.148292 -0.207005
#
# [303 rows x 3 columns]

# %%
search_all('../../../map/all_maps.txt')
mapPath = '../../../map/all_maps.txt'
mapdf = pd.read_csv(mapPath, sep='\t', index_col=0, skiprows=None, verbose=False)
mapdf
# Out:
#    0. ../../../map/all_maps.txt
#           BarcodeSequence LinkerPrimerSequence   Experiment Treatment  \
# #SampleID
# Dmel1            AAACTACA     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel2            AAATAGCA     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel3            AAGTCACA     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel4            ACAACAAC     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel5            ACAGGGAC     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel6            ACGGTAAC     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel7            AGATAATG     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel8            AGACTGTG     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel9            AGGCGATG     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel10           ATAGGAGT     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel11           ATAACGGT     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel12           ATGAAAGT     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel13           CCCAAACA     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel14           CCCGTGCA     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dmel15           CCTGGACA     AGAGTTTGATCMTGGC  Drosophila1      Dmel
# Dsim1            CACCGAAC     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim2            CACTCGAC     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim3            CATTAAAC     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim4            CTCGTATG     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim5            CTCAAGTG     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim6            CTTACATG     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim7            CGCTCAGT     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim8            CGCCGGGT     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim9            CGTCTAGT     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim10           GGGTGACA     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim11           GGGCCGCA     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim12           GGAAGCCA     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim13           GTGGAAAC     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim14           GTGATGAC     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# Dsim15           GTACACAC     AGAGTTTGATCMTGGC  Drosophila1      Dsim
# ...                   ...                  ...          ...       ...
# PBW49            TCTCCAGG     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PBW50            TCTTGGGG     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PBW51            TCCGCCGG     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PBW52            TATATATT     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PBW53            TATGAGTT     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PBW54            TACTTCTT     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PBW55            AAACGCAA     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PBW56            AAATCTAA     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PBW58            AAGACGAA     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PBW59            ACAAACCC     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PBW60            ACAGTTCC     AGAGTTTGATCMTGGC   Peromyscus       PBW
# PPO64            ACGCTGCC     AGAGTTTGATCMTGGC   Peromyscus       PPO
# PPO66            AGATCCGG     AGAGTTTGATCMTGGC   Peromyscus       PPO
# PPO67            AGACGTGG     AGAGTTTGATCMTGGC   Peromyscus       PPO
# PPO68            AGGGGGGG     AGAGTTTGATCMTGGC   Peromyscus       PPO
# PPO69            ATAGTCTT     AGAGTTTGATCMTGGC   Peromyscus       PPO
# PPO72            ATAAATTT     AGAGTTTGATCMTGGC   Peromyscus       PPO
# PPO75            ATGTAGTT     AGAGTTTGATCMTGGC   Peromyscus       PPO
# PLL76            CCCACCAA     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL77            CCCGGTAA     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL79            CCTCGGAA     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL80            CACCTCCC     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL81            CACTATCC     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL83            CATAAGCC     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL84            CTCGGCGG     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL85            CTCACTGG     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL86            CTTTCGGG     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL88            CGCTACTT     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL89            CGCCTTTT     AGAGTTTGATCMTGGC   Peromyscus       PLL
# PLL90            CGTGTGTT     AGAGTTTGATCMTGGC   Peromyscus       PLL
#
#                        Both         Spine Description
# #SampleID
# Dmel1      Drosophila1_Dmel  Invertebrate           1
# Dmel2      Drosophila1_Dmel  Invertebrate           1
# Dmel3      Drosophila1_Dmel  Invertebrate           1
# Dmel4      Drosophila1_Dmel  Invertebrate           1
# Dmel5      Drosophila1_Dmel  Invertebrate           1
# Dmel6      Drosophila1_Dmel  Invertebrate           1
# Dmel7      Drosophila1_Dmel  Invertebrate           1
# Dmel8      Drosophila1_Dmel  Invertebrate           1
# Dmel9      Drosophila1_Dmel  Invertebrate           1
# Dmel10     Drosophila1_Dmel  Invertebrate           1
# Dmel11     Drosophila1_Dmel  Invertebrate           1
# Dmel12     Drosophila1_Dmel  Invertebrate           1
# Dmel13     Drosophila1_Dmel  Invertebrate           1
# Dmel14     Drosophila1_Dmel  Invertebrate           1
# Dmel15     Drosophila1_Dmel  Invertebrate           1
# Dsim1      Drosophila1_Dsim  Invertebrate           2
# Dsim2      Drosophila1_Dsim  Invertebrate           2
# Dsim3      Drosophila1_Dsim  Invertebrate           2
# Dsim4      Drosophila1_Dsim  Invertebrate           2
# Dsim5      Drosophila1_Dsim  Invertebrate           2
# Dsim6      Drosophila1_Dsim  Invertebrate           2
# Dsim7      Drosophila1_Dsim  Invertebrate           2
# Dsim8      Drosophila1_Dsim  Invertebrate           2
# Dsim9      Drosophila1_Dsim  Invertebrate           2
# Dsim10     Drosophila1_Dsim  Invertebrate           2
# Dsim11     Drosophila1_Dsim  Invertebrate           2
# Dsim12     Drosophila1_Dsim  Invertebrate           2
# Dsim13     Drosophila1_Dsim  Invertebrate           2
# Dsim14     Drosophila1_Dsim  Invertebrate           2
# Dsim15     Drosophila1_Dsim  Invertebrate           2
# ...                     ...           ...         ...
# PBW49        Peromyscus_PBW    Vertebrate           1
# PBW50        Peromyscus_PBW    Vertebrate           1
# PBW51        Peromyscus_PBW    Vertebrate           1
# PBW52        Peromyscus_PBW    Vertebrate           1
# PBW53        Peromyscus_PBW    Vertebrate           1
# PBW54        Peromyscus_PBW    Vertebrate           1
# PBW55        Peromyscus_PBW    Vertebrate           1
# PBW56        Peromyscus_PBW    Vertebrate           1
# PBW58        Peromyscus_PBW    Vertebrate           1
# PBW59        Peromyscus_PBW    Vertebrate           1
# PBW60        Peromyscus_PBW    Vertebrate           1
# PPO64        Peromyscus_PPO    Vertebrate           1
# PPO66        Peromyscus_PPO    Vertebrate           1
# PPO67        Peromyscus_PPO    Vertebrate           1
# PPO68        Peromyscus_PPO    Vertebrate           1
# PPO69        Peromyscus_PPO    Vertebrate           1
# PPO72        Peromyscus_PPO    Vertebrate           1
# PPO75        Peromyscus_PPO    Vertebrate           1
# PLL76        Peromyscus_PLL    Vertebrate           2
# PLL77        Peromyscus_PLL    Vertebrate           2
# PLL79        Peromyscus_PLL    Vertebrate           2
# PLL80        Peromyscus_PLL    Vertebrate           2
# PLL81        Peromyscus_PLL    Vertebrate           2
# PLL83        Peromyscus_PLL    Vertebrate           2
# PLL84        Peromyscus_PLL    Vertebrate           2
# PLL85        Peromyscus_PLL    Vertebrate           2
# PLL86        Peromyscus_PLL    Vertebrate           2
# PLL88        Peromyscus_PLL    Vertebrate           2
# PLL89        Peromyscus_PLL    Vertebrate           2
# PLL90        Peromyscus_PLL    Vertebrate           2
#
# [506 rows x 7 columns]

# %%
mapColInterest = 'Experiment'

def get_color8():
    colorList = ['r','b','g','y','c','k','m','w']
    for i in colorList: yield i

# %%
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111, projection='3d')
colorNext = get_color8()
colorCombo = {}
locCombo = {}

# For each sample
for i in pPCoA.index:
    # Get map group (species or experiment)
    mdVal = mapdf.loc[i][mapColInterest]
    # If that category is already created
    if mdVal in colorCombo.keys():
        # Get it's associated color
        curColor = colorCombo[mdVal]
        # Store the location values
        locCombo[mdVal].loc[i] = [pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2]]
    else:
        # Get next color
        curColor = colorNext.next()
        # Store it's associated color
        colorCombo[mdVal] = curColor
        # Create DF for positions of that category
        locCombo[mdVal] = pd.DataFrame(columns=[0,1,2])
        # Store the location values
        locCombo[mdVal].loc[i] = [pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2]]

        
    ax.scatter(pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2], c=str(curColor), marker='o')


for i in locCombo.keys():
    print i + " Group Centers"
    print colorCombo[i]
    ax0Mean = np.mean(locCombo[i][0])
    ax1Mean = np.mean(locCombo[i][1])
    ax2Mean = np.mean(locCombo[i][2])
    print ax0Mean, ax1Mean, ax2Mean
    ax.plot([ax0Mean, ax0Mean], [ax1Mean, ax1Mean], [-0.3, ax2Mean], '--', linewidth=2, color='k', alpha=1)
    ax.scatter(ax0Mean, ax1Mean, ax2Mean, s=200, c=str(colorCombo[i]), marker=(5, 1))



ax.set_xlabel('PCoA 1 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',0])))+'%')
ax.set_ylabel('PCoA 2 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',1])))+'%')
ax.set_zlabel('PCoA 3 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',2])))+'%')


ax.set_xlim()
ax.set_zlim(-0.3)



plt.show()
# Out:
# Peromyscus Group Centers
# c
# 0.00343994741562 0.156137815583 -0.22868736223
# Hominid Group Centers
# b
# 0.00225048366332 0.116536329042 -0.11976405044
# Nasonia2 Group Centers
# y
# 0.349536658751 -0.231035037409 0.0171742225601
# Mosquito Group Centers
# g
# 0.0817021295636 0.236308988931 0.199209482702
# Drosophila2 Group Centers
# r
# -0.294384961144 -0.140885950798 0.0350011721336

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %% [markdown]
# ### Demo 3D Plot

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt


def randrange(n, vmin, vmax):
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111, projection='3d')
n = 100
for c, m, zl, zh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zl, zh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
