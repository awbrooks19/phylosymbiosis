# %% [markdown]
# <h1 style="text-align:Center; color:orange;">- iPython Notebook -</h1>

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>
# <h4 style="text-align:center; color:blue;">Andrew W. Brooks</h4>
# <h4 style="text-align:center; color:blue;">Vanderbilt Genetics Institute</h4>
# <h4 style="text-align:center; color:blue;">andrew.w.brooks(at)vanderbilt.edu</h4>
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %%
######################################################
### LOAD USEFUL TOOLS ################################
### MODULES:
#%matplotlib inline
import sys
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
### SCRIPTS:
sys.path.append("/Users/brooks/brooks_utilities/scripts/")
import python_utilities as p
#import mpld3
#mpld3.enable_notebook()

# %%
#################################################
################# SEARCH ########################    
import glob
### SEARCH FUNCTION ### regex search files (returns list of files matching regex expression)
def search(searchStr):
    return glob.glob(searchStr)

### SEARCH FUNCTION ### search and list all files in directory
def search_all(searchPath='./', printOut = True):
    if printOut == True: print_enumerate(search(searchPath + '*'))
    return search(searchPath + '*')

#################################################
################## PRINT ########################
### PRINT FUNCTION ### print a list lead by numbers
def print_enumerate(inList, leadStr="   ", sepStr=". "):
    for idx, idi in enumerate(inList): print leadStr+str(idx)+sepStr+idi

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %%
#search_all()
pcoaFiles = search_all('pcoa/', printOut=False)
print_enumerate(pcoaFiles)
# Out:
#    0. pcoa/pcoa_bray_curtis_rarefaction_833_0.txt
#    1. pcoa/pcoa_bray_curtis_rarefaction_833_1.txt
#    2. pcoa/pcoa_bray_curtis_rarefaction_833_10.txt
#    3. pcoa/pcoa_bray_curtis_rarefaction_833_11.txt
#    4. pcoa/pcoa_bray_curtis_rarefaction_833_12.txt
#    5. pcoa/pcoa_bray_curtis_rarefaction_833_13.txt
#    6. pcoa/pcoa_bray_curtis_rarefaction_833_14.txt
#    7. pcoa/pcoa_bray_curtis_rarefaction_833_15.txt
#    8. pcoa/pcoa_bray_curtis_rarefaction_833_16.txt
#    9. pcoa/pcoa_bray_curtis_rarefaction_833_17.txt
#    10. pcoa/pcoa_bray_curtis_rarefaction_833_18.txt
#    11. pcoa/pcoa_bray_curtis_rarefaction_833_19.txt
#    12. pcoa/pcoa_bray_curtis_rarefaction_833_2.txt
#    13. pcoa/pcoa_bray_curtis_rarefaction_833_20.txt
#    14. pcoa/pcoa_bray_curtis_rarefaction_833_21.txt
#    15. pcoa/pcoa_bray_curtis_rarefaction_833_22.txt
#    16. pcoa/pcoa_bray_curtis_rarefaction_833_23.txt
#    17. pcoa/pcoa_bray_curtis_rarefaction_833_24.txt
#    18. pcoa/pcoa_bray_curtis_rarefaction_833_25.txt
#    19. pcoa/pcoa_bray_curtis_rarefaction_833_26.txt
#    20. pcoa/pcoa_bray_curtis_rarefaction_833_27.txt
#    21. pcoa/pcoa_bray_curtis_rarefaction_833_28.txt
#    22. pcoa/pcoa_bray_curtis_rarefaction_833_29.txt
#    23. pcoa/pcoa_bray_curtis_rarefaction_833_3.txt
#    24. pcoa/pcoa_bray_curtis_rarefaction_833_30.txt
#    25. pcoa/pcoa_bray_curtis_rarefaction_833_31.txt
#    26. pcoa/pcoa_bray_curtis_rarefaction_833_32.txt
#    27. pcoa/pcoa_bray_curtis_rarefaction_833_33.txt
#    28. pcoa/pcoa_bray_curtis_rarefaction_833_34.txt
#    29. pcoa/pcoa_bray_curtis_rarefaction_833_35.txt
#    30. pcoa/pcoa_bray_curtis_rarefaction_833_36.txt
#    31. pcoa/pcoa_bray_curtis_rarefaction_833_37.txt
#    32. pcoa/pcoa_bray_curtis_rarefaction_833_38.txt
#    33. pcoa/pcoa_bray_curtis_rarefaction_833_39.txt
#    34. pcoa/pcoa_bray_curtis_rarefaction_833_4.txt
#    35. pcoa/pcoa_bray_curtis_rarefaction_833_40.txt
#    36. pcoa/pcoa_bray_curtis_rarefaction_833_41.txt
#    37. pcoa/pcoa_bray_curtis_rarefaction_833_42.txt
#    38. pcoa/pcoa_bray_curtis_rarefaction_833_43.txt
#    39. pcoa/pcoa_bray_curtis_rarefaction_833_44.txt
#    40. pcoa/pcoa_bray_curtis_rarefaction_833_45.txt
#    41. pcoa/pcoa_bray_curtis_rarefaction_833_46.txt
#    42. pcoa/pcoa_bray_curtis_rarefaction_833_47.txt
#    43. pcoa/pcoa_bray_curtis_rarefaction_833_48.txt
#    44. pcoa/pcoa_bray_curtis_rarefaction_833_49.txt
#    45. pcoa/pcoa_bray_curtis_rarefaction_833_5.txt
#    46. pcoa/pcoa_bray_curtis_rarefaction_833_50.txt
#    47. pcoa/pcoa_bray_curtis_rarefaction_833_51.txt
#    48. pcoa/pcoa_bray_curtis_rarefaction_833_52.txt
#    49. pcoa/pcoa_bray_curtis_rarefaction_833_53.txt
#    50. pcoa/pcoa_bray_curtis_rarefaction_833_54.txt
#    51. pcoa/pcoa_bray_curtis_rarefaction_833_55.txt
#    52. pcoa/pcoa_bray_curtis_rarefaction_833_56.txt
#    53. pcoa/pcoa_bray_curtis_rarefaction_833_57.txt
#    54. pcoa/pcoa_bray_curtis_rarefaction_833_58.txt
#    55. pcoa/pcoa_bray_curtis_rarefaction_833_59.txt
#    56. pcoa/pcoa_bray_curtis_rarefaction_833_6.txt
#    57. pcoa/pcoa_bray_curtis_rarefaction_833_60.txt
#    58. pcoa/pcoa_bray_curtis_rarefaction_833_61.txt
#    59. pcoa/pcoa_bray_curtis_rarefaction_833_62.txt
#    60. pcoa/pcoa_bray_curtis_rarefaction_833_63.txt
#    61. pcoa/pcoa_bray_curtis_rarefaction_833_64.txt
#    62. pcoa/pcoa_bray_curtis_rarefaction_833_65.txt
#    63. pcoa/pcoa_bray_curtis_rarefaction_833_66.txt
#    64. pcoa/pcoa_bray_curtis_rarefaction_833_67.txt
#    65. pcoa/pcoa_bray_curtis_rarefaction_833_68.txt
#    66. pcoa/pcoa_bray_curtis_rarefaction_833_69.txt
#    67. pcoa/pcoa_bray_curtis_rarefaction_833_7.txt
#    68. pcoa/pcoa_bray_curtis_rarefaction_833_70.txt
#    69. pcoa/pcoa_bray_curtis_rarefaction_833_71.txt
#    70. pcoa/pcoa_bray_curtis_rarefaction_833_72.txt
#    71. pcoa/pcoa_bray_curtis_rarefaction_833_73.txt
#    72. pcoa/pcoa_bray_curtis_rarefaction_833_74.txt
#    73. pcoa/pcoa_bray_curtis_rarefaction_833_75.txt
#    74. pcoa/pcoa_bray_curtis_rarefaction_833_76.txt
#    75. pcoa/pcoa_bray_curtis_rarefaction_833_77.txt
#    76. pcoa/pcoa_bray_curtis_rarefaction_833_78.txt
#    77. pcoa/pcoa_bray_curtis_rarefaction_833_79.txt
#    78. pcoa/pcoa_bray_curtis_rarefaction_833_8.txt
#    79. pcoa/pcoa_bray_curtis_rarefaction_833_80.txt
#    80. pcoa/pcoa_bray_curtis_rarefaction_833_81.txt
#    81. pcoa/pcoa_bray_curtis_rarefaction_833_82.txt
#    82. pcoa/pcoa_bray_curtis_rarefaction_833_83.txt
#    83. pcoa/pcoa_bray_curtis_rarefaction_833_84.txt
#    84. pcoa/pcoa_bray_curtis_rarefaction_833_85.txt
#    85. pcoa/pcoa_bray_curtis_rarefaction_833_86.txt
#    86. pcoa/pcoa_bray_curtis_rarefaction_833_87.txt
#    87. pcoa/pcoa_bray_curtis_rarefaction_833_88.txt
#    88. pcoa/pcoa_bray_curtis_rarefaction_833_89.txt
#    89. pcoa/pcoa_bray_curtis_rarefaction_833_9.txt
#    90. pcoa/pcoa_bray_curtis_rarefaction_833_90.txt
#    91. pcoa/pcoa_bray_curtis_rarefaction_833_91.txt
#    92. pcoa/pcoa_bray_curtis_rarefaction_833_92.txt
#    93. pcoa/pcoa_bray_curtis_rarefaction_833_93.txt
#    94. pcoa/pcoa_bray_curtis_rarefaction_833_94.txt
#    95. pcoa/pcoa_bray_curtis_rarefaction_833_95.txt
#    96. pcoa/pcoa_bray_curtis_rarefaction_833_96.txt
#    97. pcoa/pcoa_bray_curtis_rarefaction_833_97.txt
#    98. pcoa/pcoa_bray_curtis_rarefaction_833_98.txt
#    99. pcoa/pcoa_bray_curtis_rarefaction_833_99.txt

# %%
pandasDFs = []
for pcoaFile in pcoaFiles:
    pandasDFs.append(pd.read_csv(pcoaFiles[0], sep='\t', index_col=None, skiprows=None, verbose=False))

# %%
pandasPCoAs = []
pandasEigens = []

pPCoA = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][0:(len(pandasDFs[0])-2)])
pEigens = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][(len(pandasDFs[0])-2):])
pPCoA.fillna(0, inplace=True)
pEigens.fillna(0, inplace=True)

#print pPCoA
#print pEigens

for idx, i in enumerate(pandasDFs):
    #print idx
    x = pandasDFs[idx]
    x1 = pd.DataFrame(columns=[0,1,2], index=x['pc vector number'][0:(len(x)-2)])
    x1[0] = x['1'][0:(len(x)-2)].values
    x1[1] = x['2'][0:(len(x)-2)].values
    x1[2] = x['3'][0:(len(x)-2)].values
    x2 = pd.DataFrame(columns=[0,1,2], index=x['pc vector number'][(len(x)-2):])
    x2[0] = x['1'][(len(x)-2):].values
    x2[1] = x['2'][(len(x)-2):].values
    x2[2] = x['3'][(len(x)-2):].values
    #print x1.head()
    #print x2.head()
    pandasPCoAs.append(x1)
    pandasEigens.append(x2)
    pPCoA = pPCoA.add(x1)
    pEigens = pEigens.add(x2)
#print pPCoA
#print pEigens
pPCoA = pPCoA.divide(len(pandasDFs))
pEigens = pEigens.divide(len(pandasDFs))
print pEigens
print pPCoA
# Out:
#                                0          1          2
# pc vector number
# eigvals                 4.365742   3.009503   2.828266
# % variation explained  20.521065  14.146096  13.294199
#                          0         1         2
# pc vector number
# DA5               0.348063 -0.062072  0.007392
# DB5               0.363431 -0.068570  0.004579
# DC5               0.301748 -0.076075 -0.001936
# DD5               0.343679 -0.069204  0.017479
# DE5               0.322058 -0.062429  0.020327
# DF5               0.322509 -0.083278 -0.016888
# DG5               0.349488 -0.065315 -0.004135
# DH5               0.342007 -0.048536  0.023279
# DA2               0.276523  0.011623 -0.016366
# DB2               0.223164  0.050030  0.096010
# DC2               0.213834  0.104202  0.056165
# DD2               0.159730  0.079233  0.095873
# DE2               0.122214  0.088398  0.095971
# DF2               0.085362  0.105907  0.079998
# DG2               0.202604  0.094048  0.096552
# DH2               0.292852  0.001749  0.008814
# DA1               0.045660  0.252873  0.084396
# DB1              -0.085089  0.217997 -0.088105
# DC1               0.035993 -0.060356  0.159860
# DD1               0.128546 -0.145088  0.058733
# DE1               0.147531 -0.126396 -0.016652
# DF1               0.079328 -0.117786  0.165444
# DG1               0.035106 -0.016190  0.001924
# DH1               0.034560  0.012772  0.164193
# DA4               0.088817  0.090415 -0.045577
# DB4               0.076703  0.108204 -0.050140
# DC4               0.254114  0.047259 -0.057707
# DD4               0.164197  0.101387 -0.002276
# DE4               0.154090  0.113852 -0.009045
# DF4               0.252488  0.047675 -0.075169
# ...                    ...       ...       ...
# DB6              -0.325652 -0.312874  0.331731
# DC6              -0.334333 -0.284547  0.361536
# DD6              -0.352589 -0.313047  0.362955
# DE6              -0.336133 -0.299668  0.345924
# DF6              -0.318840 -0.250603  0.389977
# DG6              -0.355480 -0.315126  0.348787
# DH6              -0.366701 -0.254609  0.375104
# DA7              -0.335603 -0.189295 -0.455713
# DB7              -0.342799 -0.160572 -0.471378
# DC7              -0.338633 -0.154000 -0.438966
# DD7              -0.305619 -0.146912 -0.432254
# DE7              -0.275050 -0.120569 -0.370290
# DF7              -0.321638 -0.152597 -0.431466
# DG7              -0.340335 -0.145806 -0.401925
# DH7              -0.352131 -0.183928 -0.473235
# DA8              -0.311499  0.518852  0.069067
# DB8              -0.352192  0.475951  0.051407
# DC8              -0.339366  0.521920  0.044413
# DD8              -0.323029  0.515174  0.063869
# DF8              -0.328006  0.503938  0.056169
# DG8              -0.294713  0.467473  0.086513
# DH8              -0.240943  0.480547  0.086944
# DA3               0.140110 -0.093409 -0.149844
# DB3               0.197174 -0.139705 -0.137539
# DC3               0.193355  0.020783  0.011897
# DD3               0.179359  0.019391  0.025448
# DE3               0.233317 -0.031152  0.002433
# DF3               0.133873 -0.134347 -0.167725
# DG3               0.166041 -0.109622 -0.094585
# DH3               0.167582 -0.077354 -0.091917
#
# [63 rows x 3 columns]

# %%
mapPath = '../../../map/mosquito_map.txt'
mapdf = pd.read_csv(mapPath, sep='\t', index_col=0, skiprows=None, verbose=False)
mapdf
# Out:
#           BarcodeSequence LinkerPrimerSequence     Treatment  Description
# #SampleID
# DA1            AAATGATAGC     tgcctcccgtaggagt          FAR1           18
# DB1            CCCGCATAGC     tgcctcccgtaggagt          FAR1           18
# DC1            GGGCTATAGC     tgcctcccgtaggagt          FAR1           18
# DD1            TTTAAATAGC     tgcctcccgtaggagt          FAR1           18
# DE1            AAAGACTAGC     tgcctcccgtaggagt          FAR1           18
# DF1            CCCTTCTAGC     tgcctcccgtaggagt          FAR1           18
# DG1            GGGACCTAGC     tgcctcccgtaggagt          FAR1           18
# DH1            TTTCGCTAGC     tgcctcccgtaggagt          FAR1           18
# DA2            AAACCGTAGC     tgcctcccgtaggagt     COSTARICA           19
# DB2            CCCAGGTAGC     tgcctcccgtaggagt     COSTARICA           19
# DC2            GGGTAGTAGC     tgcctcccgtaggagt     COSTARICA           19
# DD2            TTTGTGTAGC     tgcctcccgtaggagt     COSTARICA           19
# DE2            AAAATTTAGC     tgcctcccgtaggagt     COSTARICA           19
# DF2            CCCCATTAGC     tgcctcccgtaggagt     COSTARICA           19
# DG2            GGGGGTTAGC     tgcctcccgtaggagt     COSTARICA           19
# DH2            TTTTCTTAGC     tgcctcccgtaggagt     COSTARICA           19
# DA3            AAGCAATAGC     tgcctcccgtaggagt          YOLO           20
# DB3            CCTATATAGC     tgcctcccgtaggagt          YOLO           20
# DC3            GGAGTCTAGC     tgcctcccgtaggagt          YOLO           20
# DD3            TTCTACTAGC     tgcctcccgtaggagt          YOLO           20
# DE3            AAGTTGTAGC     tgcctcccgtaggagt          YOLO           20
# DF3            CCTGAGTAGC     tgcctcccgtaggagt          YOLO           20
# DG3            GGAAATTAGC     tgcctcccgtaggagt          YOLO           20
# DH3            TTCCTTTAGC     tgcctcccgtaggagt          YOLO           20
# DA4            ACAGAAGCGC     tgcctcccgtaggagt         FUMOZ           21
# DB4            CACTTAGCGC     tgcctcccgtaggagt         FUMOZ           21
# DC4            GTGACAGCGC     tgcctcccgtaggagt         FUMOZ           21
# DD4            TGTCGAGCGC     tgcctcccgtaggagt         FUMOZ           21
# DE4            ACATGCGCGC     tgcctcccgtaggagt         FUMOZ           21
# DF4            CACGCCGCGC     tgcctcccgtaggagt         FUMOZ           21
# ...                   ...                  ...           ...          ...
# DC6            GTATCCGCGC     tgcctcccgtaggagt          GORO           23
# DD6            TGCGGCGCGC     tgcctcccgtaggagt          GORO           23
# DE6            ACGGCGGCGC     tgcctcccgtaggagt          GORO           23
# DF6            CATTGGGCGC     tgcctcccgtaggagt          GORO           23
# DG6            GTACGTGCGC     tgcctcccgtaggagt          GORO           23
# DH6            TGCACTGCGC     tgcctcccgtaggagt          GORO           23
# DA7            AGACCACGGC     tgcctcccgtaggagt       MALINIH           24
# DB7            CTCAGACGGC     tgcctcccgtaggagt       MALINIH           24
# DC7            GAGTAACGGC     tgcctcccgtaggagt       MALINIH           24
# DD7            TCTGTACGGC     tgcctcccgtaggagt       MALINIH           24
# DE7            AGAATCCGGC     tgcctcccgtaggagt       MALINIH           24
# DF7            CTCCACCGGC     tgcctcccgtaggagt       MALINIH           24
# DG7            GAGGGCCGGC     tgcctcccgtaggagt       MALINIH           24
# DH7            TCTTCCCGGC     tgcctcccgtaggagt       MALINIH           24
# DA8            AGATGGCGGC     tgcctcccgtaggagt          SENN           25
# DB8            CTCGCGCGGC     tgcctcccgtaggagt          SENN           25
# DC8            GAGCTGCGGC     tgcctcccgtaggagt          SENN           25
# DD8            TCTAAGCGGC     tgcctcccgtaggagt          SENN           25
# DE8            AGAGATCGGC     tgcctcccgtaggagt          SENN           25
# DF8            CTCTTTCGGC     tgcctcccgtaggagt          SENN           25
# DG8            GAGACTCGGC     tgcctcccgtaggagt          SENN           25
# DH8            TCTCGTCGGC     tgcctcccgtaggagt          SENN           25
# DA9            AGGTTACGGC     tgcctcccgtaggagt       FAR1H2O           26
# DB9            CTTGAACGGC     tgcctcccgtaggagt  COSTARICAH2O           27
# DC9            GAAAACCGGC     tgcctcccgtaggagt       YOLOH2O           28
# DD9            TCCCTCCGGC     tgcctcccgtaggagt      FUMOZH2O           29
# DE9            AGGCAGCGGC     tgcctcccgtaggagt   ALBOPICTH2O           30
# DF9            CTTATGCGGC     tgcctcccgtaggagt       GOROH2O           31
# DG9            GAAGTTCGGC     tgcctcccgtaggagt    MALINIHH2O           32
# DH9            TCCTATCGGC     tgcctcccgtaggagt       SENNH2O           33
#
# [72 rows x 4 columns]

# %%
mapColInterest = 'Treatment'

def get_color8():
    colorList = ['r','b','g','y','c','k','m','w']
    for i in colorList: yield i

# %%
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111, projection='3d')
colorNext = get_color8()
colorCombo = {}
locCombo = {}

# For each sample
for i in pPCoA.index:
    # Get map group (species or experiment)
    mdVal = mapdf.loc[i][mapColInterest]
    # If that category is already created
    if mdVal in colorCombo.keys():
        # Get it's associated color
        curColor = colorCombo[mdVal]
        # Store the location values
        locCombo[mdVal].loc[i] = [pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2]]
    else:
        # Get next color
        curColor = colorNext.next()
        # Store it's associated color
        colorCombo[mdVal] = curColor
        # Create DF for positions of that category
        locCombo[mdVal] = pd.DataFrame(columns=[0,1,2])
        # Store the location values
        locCombo[mdVal].loc[i] = [pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2]]

        
    ax.scatter(pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2], c=str(curColor), marker='o')


for i in locCombo.keys():
    print i + " Group Centers"
    print colorCombo[i]
    ax0Mean = np.mean(locCombo[i][0])
    ax1Mean = np.mean(locCombo[i][1])
    ax2Mean = np.mean(locCombo[i][2])
    print ax0Mean, ax1Mean, ax2Mean
    ax.plot([ax0Mean, ax0Mean], [ax1Mean, ax1Mean], [-0.6, ax2Mean], '--', linewidth=2, color='k', alpha=1)
    ax.scatter(ax0Mean, ax1Mean, ax2Mean, s=200, c=str(colorCombo[i]), marker=(5, 1))



ax.set_xlabel('PCoA 1 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',0])))+'%')
ax.set_ylabel('PCoA 2 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',1])))+'%')
ax.set_zlabel('PCoA 3 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',2])))+'%')


ax.set_xlim()
ax.set_zlim()



plt.show()

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %% [markdown]
# ### Demo 3D Plot

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt


def randrange(n, vmin, vmax):
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111, projection='3d')
n = 100
for c, m, zl, zh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zl, zh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
