# %% [markdown]
# <h1 style="text-align:Center; color:orange;">- iPython Notebook -</h1>

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>
# <h4 style="text-align:center; color:blue;">Andrew W. Brooks</h4>
# <h4 style="text-align:center; color:blue;">Vanderbilt Genetics Institute</h4>
# <h4 style="text-align:center; color:blue;">andrew.w.brooks(at)vanderbilt.edu</h4>
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %%
######################################################
### LOAD USEFUL TOOLS ################################
### MODULES:
#%matplotlib inline
import sys
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
### SCRIPTS:
sys.path.append("/Users/brooks/brooks_utilities/scripts/")
import python_utilities as p
#import mpld3
#mpld3.enable_notebook()

# %%
#################################################
################# SEARCH ########################    
import glob
### SEARCH FUNCTION ### regex search files (returns list of files matching regex expression)
def search(searchStr):
    return glob.glob(searchStr)

### SEARCH FUNCTION ### search and list all files in directory
def search_all(searchPath='./', printOut = True):
    if printOut == True: print_enumerate(search(searchPath + '*'))
    return search(searchPath + '*')

#################################################
################## PRINT ########################
### PRINT FUNCTION ### print a list lead by numbers
def print_enumerate(inList, leadStr="   ", sepStr=". "):
    for idx, idi in enumerate(inList): print leadStr+str(idx)+sepStr+idi

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %%
#search_all()
pcoaFiles = search_all('pcoa/', printOut=False)
print_enumerate(pcoaFiles)
# Out:
#    0. pcoa/pcoa_bray_curtis_rarefaction_14490_0.txt
#    1. pcoa/pcoa_bray_curtis_rarefaction_14490_1.txt
#    2. pcoa/pcoa_bray_curtis_rarefaction_14490_10.txt
#    3. pcoa/pcoa_bray_curtis_rarefaction_14490_11.txt
#    4. pcoa/pcoa_bray_curtis_rarefaction_14490_12.txt
#    5. pcoa/pcoa_bray_curtis_rarefaction_14490_13.txt
#    6. pcoa/pcoa_bray_curtis_rarefaction_14490_14.txt
#    7. pcoa/pcoa_bray_curtis_rarefaction_14490_15.txt
#    8. pcoa/pcoa_bray_curtis_rarefaction_14490_16.txt
#    9. pcoa/pcoa_bray_curtis_rarefaction_14490_17.txt
#    10. pcoa/pcoa_bray_curtis_rarefaction_14490_18.txt
#    11. pcoa/pcoa_bray_curtis_rarefaction_14490_19.txt
#    12. pcoa/pcoa_bray_curtis_rarefaction_14490_2.txt
#    13. pcoa/pcoa_bray_curtis_rarefaction_14490_20.txt
#    14. pcoa/pcoa_bray_curtis_rarefaction_14490_21.txt
#    15. pcoa/pcoa_bray_curtis_rarefaction_14490_22.txt
#    16. pcoa/pcoa_bray_curtis_rarefaction_14490_23.txt
#    17. pcoa/pcoa_bray_curtis_rarefaction_14490_24.txt
#    18. pcoa/pcoa_bray_curtis_rarefaction_14490_25.txt
#    19. pcoa/pcoa_bray_curtis_rarefaction_14490_26.txt
#    20. pcoa/pcoa_bray_curtis_rarefaction_14490_27.txt
#    21. pcoa/pcoa_bray_curtis_rarefaction_14490_28.txt
#    22. pcoa/pcoa_bray_curtis_rarefaction_14490_29.txt
#    23. pcoa/pcoa_bray_curtis_rarefaction_14490_3.txt
#    24. pcoa/pcoa_bray_curtis_rarefaction_14490_30.txt
#    25. pcoa/pcoa_bray_curtis_rarefaction_14490_31.txt
#    26. pcoa/pcoa_bray_curtis_rarefaction_14490_32.txt
#    27. pcoa/pcoa_bray_curtis_rarefaction_14490_33.txt
#    28. pcoa/pcoa_bray_curtis_rarefaction_14490_34.txt
#    29. pcoa/pcoa_bray_curtis_rarefaction_14490_35.txt
#    30. pcoa/pcoa_bray_curtis_rarefaction_14490_36.txt
#    31. pcoa/pcoa_bray_curtis_rarefaction_14490_37.txt
#    32. pcoa/pcoa_bray_curtis_rarefaction_14490_38.txt
#    33. pcoa/pcoa_bray_curtis_rarefaction_14490_39.txt
#    34. pcoa/pcoa_bray_curtis_rarefaction_14490_4.txt
#    35. pcoa/pcoa_bray_curtis_rarefaction_14490_40.txt
#    36. pcoa/pcoa_bray_curtis_rarefaction_14490_41.txt
#    37. pcoa/pcoa_bray_curtis_rarefaction_14490_42.txt
#    38. pcoa/pcoa_bray_curtis_rarefaction_14490_43.txt
#    39. pcoa/pcoa_bray_curtis_rarefaction_14490_44.txt
#    40. pcoa/pcoa_bray_curtis_rarefaction_14490_45.txt
#    41. pcoa/pcoa_bray_curtis_rarefaction_14490_46.txt
#    42. pcoa/pcoa_bray_curtis_rarefaction_14490_47.txt
#    43. pcoa/pcoa_bray_curtis_rarefaction_14490_48.txt
#    44. pcoa/pcoa_bray_curtis_rarefaction_14490_49.txt
#    45. pcoa/pcoa_bray_curtis_rarefaction_14490_5.txt
#    46. pcoa/pcoa_bray_curtis_rarefaction_14490_50.txt
#    47. pcoa/pcoa_bray_curtis_rarefaction_14490_51.txt
#    48. pcoa/pcoa_bray_curtis_rarefaction_14490_52.txt
#    49. pcoa/pcoa_bray_curtis_rarefaction_14490_53.txt
#    50. pcoa/pcoa_bray_curtis_rarefaction_14490_54.txt
#    51. pcoa/pcoa_bray_curtis_rarefaction_14490_55.txt
#    52. pcoa/pcoa_bray_curtis_rarefaction_14490_56.txt
#    53. pcoa/pcoa_bray_curtis_rarefaction_14490_57.txt
#    54. pcoa/pcoa_bray_curtis_rarefaction_14490_58.txt
#    55. pcoa/pcoa_bray_curtis_rarefaction_14490_59.txt
#    56. pcoa/pcoa_bray_curtis_rarefaction_14490_6.txt
#    57. pcoa/pcoa_bray_curtis_rarefaction_14490_60.txt
#    58. pcoa/pcoa_bray_curtis_rarefaction_14490_61.txt
#    59. pcoa/pcoa_bray_curtis_rarefaction_14490_62.txt
#    60. pcoa/pcoa_bray_curtis_rarefaction_14490_63.txt
#    61. pcoa/pcoa_bray_curtis_rarefaction_14490_64.txt
#    62. pcoa/pcoa_bray_curtis_rarefaction_14490_65.txt
#    63. pcoa/pcoa_bray_curtis_rarefaction_14490_66.txt
#    64. pcoa/pcoa_bray_curtis_rarefaction_14490_67.txt
#    65. pcoa/pcoa_bray_curtis_rarefaction_14490_68.txt
#    66. pcoa/pcoa_bray_curtis_rarefaction_14490_69.txt
#    67. pcoa/pcoa_bray_curtis_rarefaction_14490_7.txt
#    68. pcoa/pcoa_bray_curtis_rarefaction_14490_70.txt
#    69. pcoa/pcoa_bray_curtis_rarefaction_14490_71.txt
#    70. pcoa/pcoa_bray_curtis_rarefaction_14490_72.txt
#    71. pcoa/pcoa_bray_curtis_rarefaction_14490_73.txt
#    72. pcoa/pcoa_bray_curtis_rarefaction_14490_74.txt
#    73. pcoa/pcoa_bray_curtis_rarefaction_14490_75.txt
#    74. pcoa/pcoa_bray_curtis_rarefaction_14490_76.txt
#    75. pcoa/pcoa_bray_curtis_rarefaction_14490_77.txt
#    76. pcoa/pcoa_bray_curtis_rarefaction_14490_78.txt
#    77. pcoa/pcoa_bray_curtis_rarefaction_14490_79.txt
#    78. pcoa/pcoa_bray_curtis_rarefaction_14490_8.txt
#    79. pcoa/pcoa_bray_curtis_rarefaction_14490_80.txt
#    80. pcoa/pcoa_bray_curtis_rarefaction_14490_81.txt
#    81. pcoa/pcoa_bray_curtis_rarefaction_14490_82.txt
#    82. pcoa/pcoa_bray_curtis_rarefaction_14490_83.txt
#    83. pcoa/pcoa_bray_curtis_rarefaction_14490_84.txt
#    84. pcoa/pcoa_bray_curtis_rarefaction_14490_85.txt
#    85. pcoa/pcoa_bray_curtis_rarefaction_14490_86.txt
#    86. pcoa/pcoa_bray_curtis_rarefaction_14490_87.txt
#    87. pcoa/pcoa_bray_curtis_rarefaction_14490_88.txt
#    88. pcoa/pcoa_bray_curtis_rarefaction_14490_89.txt
#    89. pcoa/pcoa_bray_curtis_rarefaction_14490_9.txt
#    90. pcoa/pcoa_bray_curtis_rarefaction_14490_90.txt
#    91. pcoa/pcoa_bray_curtis_rarefaction_14490_91.txt
#    92. pcoa/pcoa_bray_curtis_rarefaction_14490_92.txt
#    93. pcoa/pcoa_bray_curtis_rarefaction_14490_93.txt
#    94. pcoa/pcoa_bray_curtis_rarefaction_14490_94.txt
#    95. pcoa/pcoa_bray_curtis_rarefaction_14490_95.txt
#    96. pcoa/pcoa_bray_curtis_rarefaction_14490_96.txt
#    97. pcoa/pcoa_bray_curtis_rarefaction_14490_97.txt
#    98. pcoa/pcoa_bray_curtis_rarefaction_14490_98.txt
#    99. pcoa/pcoa_bray_curtis_rarefaction_14490_99.txt

# %%
pandasDFs = []
for pcoaFile in pcoaFiles:
    pandasDFs.append(pd.read_csv(pcoaFiles[0], sep='\t', index_col=None, skiprows=None, verbose=False))

# %%
pandasPCoAs = []
pandasEigens = []

pPCoA = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][0:(len(pandasDFs[0])-2)])
pEigens = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][(len(pandasDFs[0])-2):])
pPCoA.fillna(0, inplace=True)
pEigens.fillna(0, inplace=True)

#print pPCoA
#print pEigens

for idx, i in enumerate(pandasDFs):
    #print idx
    x = pandasDFs[idx]
    x1 = pd.DataFrame(columns=[0,1,2], index=x['pc vector number'][0:(len(x)-2)])
    x1[0] = x['1'][0:(len(x)-2)].values
    x1[1] = x['2'][0:(len(x)-2)].values
    x1[2] = x['3'][0:(len(x)-2)].values
    x2 = pd.DataFrame(columns=[0,1,2], index=x['pc vector number'][(len(x)-2):])
    x2[0] = x['1'][(len(x)-2):].values
    x2[1] = x['2'][(len(x)-2):].values
    x2[2] = x['3'][(len(x)-2):].values
    #print x1.head()
    #print x2.head()
    pandasPCoAs.append(x1)
    pandasEigens.append(x2)
    pPCoA = pPCoA.add(x1)
    pEigens = pEigens.add(x2)
#print pPCoA
#print pEigens
pPCoA = pPCoA.divide(len(pandasDFs))
pEigens = pEigens.divide(len(pandasDFs))
print pEigens
print pPCoA
# Out:
#                                0          1         2
# pc vector number
# eigvals                 1.734384   1.146693  0.916005
# % variation explained  16.906825  11.178000  8.929247
#                          0         1         2
# pc vector number
# CR89             -0.216535  0.080072 -0.059550
# CR95             -0.118271 -0.081391 -0.106816
# CR334             0.077087 -0.143998 -0.088171
# CR348             0.073043 -0.000290  0.071052
# CR457            -0.249004 -0.174853 -0.213302
# CR458            -0.235409 -0.205357 -0.269387
# CR464             0.047546 -0.380910 -0.247477
# CR469             0.174177 -0.051560 -0.039946
# CR470             0.176081  0.002413  0.031222
# CR2528           -0.498737  0.155425 -0.038184
# CR2530           -0.499029  0.220429  0.029085
# GM173             0.166140  0.000512 -0.014441
# KSG242            0.077174 -0.212556  0.493146
# KSG246            0.062583 -0.174436  0.522999
# KSG477           -0.032548 -0.053770  0.191477
# KSG0645           0.350608  0.293172 -0.086421
# KSG0647           0.309726  0.255124 -0.109762
# KSG0652           0.284278  0.297864  0.017691
# KSG0660           0.350203  0.279671 -0.080987
# KSG0673           0.330492  0.255452 -0.120127
# KSG1471          -0.459520  0.239213  0.051850
# KSG1507          -0.412404  0.256338  0.066935
# US1AZ            -0.025405 -0.051481  0.209315
# WCR464            0.082512 -0.368906 -0.226592
# WLK3              0.153955 -0.194185  0.068065
# WLK12             0.031257 -0.241991 -0.051675

# %%
mapPath = '../../../map/map.txt'
mapdf = pd.read_csv(mapPath, sep='\t', index_col=0, skiprows=None, verbose=False)
mapdf
# Out:
#           BarcodeSequence   LinkerPrimerSequence    Genus  \
# #SampleID
# CR464        AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# KSG246       AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# US1AZ        AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT     Homo
# WLK3         AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# KSG477       AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT     Homo
# WLK12        AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# KSG0652      AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# KSG242       AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# KSG1507      AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT  Gorilla
# CR2530       AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT  Gorilla
# CR334        AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# CR469        AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# KSG0673      AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# CR2528       AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT  Gorilla
# KSG0647      AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# KSG0660      AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# KSG0645      AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# KSG1471      AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT  Gorilla
# CR348        AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# WCR464       AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# GM173        AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# CR457        AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# CR95         AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# CR89         AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# CR470        AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
# CR458        AAAAAAAAAAAA  CATGCTGCCTCCCGTAGGAGT      Pan
#
#                               Species   Ethnicity   Site  Sequences  \
# #SampleID
# CR464         Troglodytes_Troglodytes         Ptt  Fecal      16947
# KSG246     Troglodytes_Schweinfurthii         Pts  Fecal      19832
# US1AZ                          Sapien  Hs_unknown  Fecal      20015
# WLK3       Troglodytes_Schweinfurthii         Pts  Fecal      20304
# KSG477                         Sapien  Hs_Unknown  Fecal      24345
# WLK12      Troglodytes_Schweinfurthii         Pts  Fecal      24599
# KSG0652                       Panicus          Pp  Fecal      25224
# KSG242     Troglodytes_Schweinfurthii         Pts  Fecal      25696
# KSG1507                      Beringei          Gb  Fecal      30468
# CR2530                        Gorilla          Gg  Fecal      31426
# CR334         Troglodytes_Troglodytes         Ptt  Fecal      32203
# CR469         Troglodytes_Troglodytes         Ptt  Fecal      32242
# KSG0673                       Panicus          Pp  Fecal      33340
# CR2528                        Gorilla          Gg  Fecal      33511
# KSG0647                       Panicus          Pp  Fecal      34071
# KSG0660                       Panicus          Pp  Fecal      34156
# KSG0645                       Panicus          Pp  Fecal      34304
# KSG1471                      Beringei          Gb  Fecal      45533
# CR348         Troglodytes_Troglodytes         Ptt  Fecal      49060
# WCR464        Troglodytes_Troglodytes         Ptt  Fecal      61554
# GM173      Troglodytes_Schweinfurthii         Pts  Fecal      66711
# CR457             Troglodytes_Ellioti         Ptv  Fecal      76174
# CR95          Troglodytes_Troglodytes         Ptt  Fecal      93360
# CR89          Troglodytes_Troglodytes         Ptt  Fecal     102767
# CR470         Troglodytes_Troglodytes         Ptt  Fecal     121484
# CR458             Troglodytes_Ellioti         Ptv  Fecal     198388
#
#                             Description
# #SampleID
# CR464         P_troglodytes_troglodytes
# KSG246     P_troglodytes_schweinfurthii
# US1AZ                       Homo_sapien
# WLK3       P_troglodytes_schweinfurthii
# KSG477                      Homo_sapien
# WLK12      P_troglodytes_schweinfurthii
# KSG0652                    Pan_paniscus
# KSG242     P_troglodytes_schweinfurthii
# KSG1507                Gorilla_beringei
# CR2530                  Gorilla_gorilla
# CR334         P_troglodytes_troglodytes
# CR469         P_troglodytes_troglodytes
# KSG0673                    Pan_paniscus
# CR2528                  Gorilla_gorilla
# KSG0647                    Pan_paniscus
# KSG0660                    Pan_paniscus
# KSG0645                    Pan_paniscus
# KSG1471                Gorilla_beringei
# CR348         P_troglodytes_troglodytes
# WCR464        P_troglodytes_troglodytes
# GM173      P_troglodytes_schweinfurthii
# CR457             P_troglodytes_ellioti
# CR95          P_troglodytes_troglodytes
# CR89          P_troglodytes_troglodytes
# CR470         P_troglodytes_troglodytes
# CR458             P_troglodytes_ellioti

# %%
mapColInterest = 'Description'

def get_color8():
    colorList = ['r','b','g','y','c','k','m','w']
    for i in colorList: yield i

# %%
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111, projection='3d')
colorNext = get_color8()
colorCombo = {}
locCombo = {}

# For each sample
for i in pPCoA.index:
    # Get map group (species or experiment)
    mdVal = mapdf.loc[i][mapColInterest]
    # If that category is already created
    if mdVal in colorCombo.keys():
        # Get it's associated color
        curColor = colorCombo[mdVal]
        # Store the location values
        locCombo[mdVal].loc[i] = [pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2]]
    else:
        # Get next color
        curColor = colorNext.next()
        # Store it's associated color
        colorCombo[mdVal] = curColor
        # Create DF for positions of that category
        locCombo[mdVal] = pd.DataFrame(columns=[0,1,2])
        # Store the location values
        locCombo[mdVal].loc[i] = [pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2]]

        
    ax.scatter(pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2], c=str(curColor), marker='o')


for i in locCombo.keys():
    print i + " Group Centers"
    print colorCombo[i]
    ax0Mean = np.mean(locCombo[i][0])
    ax1Mean = np.mean(locCombo[i][1])
    ax2Mean = np.mean(locCombo[i][2])
    print ax0Mean, ax1Mean, ax2Mean
    ax.plot([ax0Mean, ax0Mean], [ax1Mean, ax1Mean], [-0.3, ax2Mean], '--', linewidth=2, color='k', alpha=1)
    ax.scatter(ax0Mean, ax1Mean, ax2Mean, s=200, c=str(colorCombo[i]), marker=(5, 1))



ax.set_xlabel('PCoA 1 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',0])))+'%')
ax.set_ylabel('PCoA 2 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',1])))+'%')
ax.set_zlabel('PCoA 3 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',2])))+'%')


ax.set_xlim()
ax.set_zlim(-0.3)



plt.show()

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %% [markdown]
# ### Demo 3D Plot

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt


def randrange(n, vmin, vmax):
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111, projection='3d')
n = 100
for c, m, zl, zh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zl, zh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
