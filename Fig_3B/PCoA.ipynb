# %% [markdown]
# <h1 style="text-align:Center; color:orange;">- iPython Notebook -</h1>

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>
# <h4 style="text-align:center; color:blue;">Andrew W. Brooks</h4>
# <h4 style="text-align:center; color:blue;">Vanderbilt Genetics Institute</h4>
# <h4 style="text-align:center; color:blue;">andrew.w.brooks(at)vanderbilt.edu</h4>
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %%
######################################################
### LOAD USEFUL TOOLS ################################
### MODULES:
#%matplotlib inline
import sys
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
### SCRIPTS:
sys.path.append("/Users/brooks/brooks_utilities/scripts/")
import python_utilities as p
#import mpld3
#mpld3.enable_notebook()

# %%
#################################################
################# SEARCH ########################    
import glob
### SEARCH FUNCTION ### regex search files (returns list of files matching regex expression)
def search(searchStr):
    return glob.glob(searchStr)

### SEARCH FUNCTION ### search and list all files in directory
def search_all(searchPath='./', printOut = True):
    if printOut == True: print_enumerate(search(searchPath + '*'))
    return search(searchPath + '*')

#################################################
################## PRINT ########################
### PRINT FUNCTION ### print a list lead by numbers
def print_enumerate(inList, leadStr="   ", sepStr=". "):
    for idx, idi in enumerate(inList): print leadStr+str(idx)+sepStr+idi

# %%
xxx = search_all('pcoa/', printOut=True)

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %%
#search_all()
pcoaFiles = search_all('pcoa/', printOut=True)
print_enumerate(pcoaFiles)

# %%
pandasDFs = []
for pcoaFile in pcoaFiles:
    pandasDFs.append(pd.read_csv(pcoaFiles[0], sep='\t', index_col=None, skiprows=None, verbose=False))

# %%
pandasPCoAs = []
pandasEigens = []

pPCoA = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][0:(len(pandasDFs[0])-2)])
pEigens = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][(len(pandasDFs[0])-2):])
pPCoA.fillna(0, inplace=True)
pEigens.fillna(0, inplace=True)

#print pPCoA
#print pEigens

for idx, i in enumerate(pandasDFs):
    #print idx
    x = pandasDFs[idx]
    x1 = pd.DataFrame(columns=[0,1,2], index=x['pc vector number'][0:(len(x)-2)])
    x1[0] = x['1'][0:(len(x)-2)].values
    x1[1] = x['2'][0:(len(x)-2)].values
    x1[2] = x['3'][0:(len(x)-2)].values
    x2 = pd.DataFrame(columns=[0,1,2], index=x['pc vector number'][(len(x)-2):])
    x2[0] = x['1'][(len(x)-2):].values
    x2[1] = x['2'][(len(x)-2):].values
    x2[2] = x['3'][(len(x)-2):].values
    #print x1.head()
    #print x2.head()
    pandasPCoAs.append(x1)
    pandasEigens.append(x2)
    pPCoA = pPCoA.add(x1)
    pEigens = pEigens.add(x2)
#print pPCoA
#print pEigens
pPCoA = pPCoA.divide(len(pandasDFs))
pEigens = pEigens.divide(len(pandasDFs))
print pEigens
print pPCoA
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-42e2d5e9df6e> in <module>()
#       2 pandasEigens = []
#       3
# ----> 4 pPCoA = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][0:(len(pandasDFs[0])-2)])
#       5 pEigens = pd.DataFrame(columns=[0,1,2], index=pandasDFs[0]['pc vector number'][(len(pandasDFs[0])-2):])
#       6 pPCoA.fillna(0, inplace=True)
#
# IndexError: list index out of range

# %%
mapPath = '../../../map/nasonia_map.txt'
mapdf = pd.read_csv(mapPath, sep='\t', index_col=0, skiprows=None, verbose=False)
mapdf
# Out:
#           BarcodeSequence LinkerPrimerSequence Treatment  Description
# #SampleID
# AA1            AAAAAAAAGC     tgcctcccgtaggagt       vit            1
# AB1            CCCCTAAAGC     tgcctcccgtaggagt       vit            1
# AC1            GGGGCAAAGC     tgcctcccgtaggagt       vit            1
# AD1            TTTTGAAAGC     tgcctcccgtaggagt       vit            1
# AE1            AAACGCAAGC     tgcctcccgtaggagt       vit            1
# AF1            CCCACCAAGC     tgcctcccgtaggagt       vit            1
# AG1            GGGTTCAAGC     tgcctcccgtaggagt       vit            1
# AH1            TTTGACAAGC     tgcctcccgtaggagt       vit            1
# AA2            AAAGTGAAGC     tgcctcccgtaggagt       vit            1
# AB2            CCCTAGAAGC     tgcctcccgtaggagt       vit            1
# AC2            GGGAGGAAGC     tgcctcccgtaggagt       vit            1
# AD2            TTTCCGAAGC     tgcctcccgtaggagt       vit            1
# AE2            AAATCTAAGC     tgcctcccgtaggagt       vit            1
# AF2            CCCGGTAAGC     tgcctcccgtaggagt       vit            1
# AG2            GGGCATAAGC     tgcctcccgtaggagt       vit            1
# AH2            TTTATTAAGC     tgcctcccgtaggagt       vit            2
# AA3            AAGGGAAAGC     tgcctcccgtaggagt       gir            2
# AB3            CCTTCAAAGC     tgcctcccgtaggagt       gir            2
# AC3            GGACCCAAGC     tgcctcccgtaggagt       gir            2
# AD3            TTCAGCAAGC     tgcctcccgtaggagt       gir            2
# AE3            AAGACGAAGC     tgcctcccgtaggagt       gir            2
# AF3            CCTCGGAAGC     tgcctcccgtaggagt       gir            2
# AG3            GGATGTAAGC     tgcctcccgtaggagt       gir            2
# AH3            TTCGCTAAGC     tgcctcccgtaggagt       gir            2
# AA4            ACACGACCGC     tgcctcccgtaggagt       gir            2
# AB4            CACACACCGC     tgcctcccgtaggagt       gir            2
# AC4            GTGTTACCGC     tgcctcccgtaggagt       gir            2
# AD4            TGTGAACCGC     tgcctcccgtaggagt       gir            2
# AE4            ACAAACCCGC     tgcctcccgtaggagt       gir            2
# AF4            CACCTCCCGC     tgcctcccgtaggagt       gir            2
# ...                   ...                  ...       ...          ...
# AC7            GAGAGAGGGC     tgcctcccgtaggagt      long            4
# AD7            TCTCCAGGGC     tgcctcccgtaggagt      long            4
# AE7            AGATCCGGGC     tgcctcccgtaggagt      long            4
# AF7            CTCGGCGGGC     tgcctcccgtaggagt      long            4
# AG7            GAGCACGGGC     tgcctcccgtaggagt      long            4
# AH7            TCTATCGGGC     tgcctcccgtaggagt      long            4
# AA8            AGAAAGGGGC     tgcctcccgtaggagt      long            4
# AB8            CTCCTGGGGC     tgcctcccgtaggagt      long            4
# AC8            GAGGCGGGGC     tgcctcccgtaggagt      long            4
# AD8            TCTTGGGGGC     tgcctcccgtaggagt      long            4
# AE8            AGACGTGGGC     tgcctcccgtaggagt      long            4
# AF8            CTCACTGGGC     tgcctcccgtaggagt      long            4
# AG8            GAGTTTGGGC     tgcctcccgtaggagt      long            4
# AH8            TCTGATGGGC     tgcctcccgtaggagt      long            4
# AA9            AGGACAGGGC     tgcctcccgtaggagt       uni            5
# AB9            CTTCGAGGGC     tgcctcccgtaggagt       uni            5
# AC9            GAATGCGGGC     tgcctcccgtaggagt       uni            5
# AD9            TCCGCCGGGC     tgcctcccgtaggagt       uni            5
# AE9            AGGGGGGGGC     tgcctcccgtaggagt       uni            5
# AF9            CTTTCGGGGC     tgcctcccgtaggagt       uni            5
# AG9            GAACCTGGGC     tgcctcccgtaggagt       uni            5
# AH9            TCCAGTGGGC     tgcctcccgtaggagt       uni            5
# AA10           ATATCATTGC     tgcctcccgtaggagt       uni            5
# AB10           CGCGGATTGC     tgcctcccgtaggagt       uni            5
# AC10           GCGCAATTGC     tgcctcccgtaggagt       uni            5
# AD10           TATATATTGC     tgcctcccgtaggagt       uni            5
# AE10           ATAGTCTTGC     tgcctcccgtaggagt       uni            5
# AF10           CGCTACTTGC     tgcctcccgtaggagt       uni            5
# AG10           GCGAGCTTGC     tgcctcccgtaggagt       uni            5
# AH10           TATCCCTTGC     tgcctcccgtaggagt       uni            5
#
# [80 rows x 4 columns]

# %%
mapColInterest = 'Treatment'

def get_color8():
    colorList = ['r','b','g','y','c','k','m','w']
    for i in colorList: yield i

# %%
fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111, projection='3d')
colorNext = get_color8()
colorCombo = {}
locCombo = {}

# For each sample
for i in pPCoA.index:
    # Get map group (species or experiment)
    mdVal = mapdf.loc[i][mapColInterest]
    # If that category is already created
    if mdVal in colorCombo.keys():
        # Get it's associated color
        curColor = colorCombo[mdVal]
        # Store the location values
        locCombo[mdVal].loc[i] = [pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2]]
    else:
        # Get next color
        curColor = colorNext.next()
        # Store it's associated color
        colorCombo[mdVal] = curColor
        # Create DF for positions of that category
        locCombo[mdVal] = pd.DataFrame(columns=[0,1,2])
        # Store the location values
        locCombo[mdVal].loc[i] = [pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2]]

        
    ax.scatter(pPCoA.loc[i,0], pPCoA.loc[i,1], pPCoA.loc[i,2], c=str(curColor), marker='o')


for i in locCombo.keys():
    print i + " Group Centers"
    print colorCombo[i]
    ax0Mean = np.mean(locCombo[i][0])
    ax1Mean = np.mean(locCombo[i][1])
    ax2Mean = np.mean(locCombo[i][2])
    print ax0Mean, ax1Mean, ax2Mean
    ax.plot([ax0Mean, ax0Mean], [ax1Mean, ax1Mean], [-0.6, ax2Mean], '--', linewidth=2, color='k', alpha=1)
    ax.scatter(ax0Mean, ax1Mean, ax2Mean, s=200, c=str(colorCombo[i]), marker=(5, 1))



ax.set_xlabel('PCoA 1 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',0])))+'%')
ax.set_ylabel('PCoA 2 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',1])))+'%')
ax.set_zlabel('PCoA 3 - '+ str(float("{0:.2f}".format(pEigens.loc['% variation explained',2])))+'%')


ax.set_xlim()
ax.set_zlim()



plt.show()
# Out:
# uni Group Centers
# y
# -0.497165999171 -0.0687824525661 -0.0183474976526
# vit Group Centers
# c
# 0.168303488522 -0.15425765361 0.0989399252477
# oni Group Centers
# g
# 0.120418528458 -0.0363582177204 -0.0242504886939
# gir Group Centers
# r
# 0.0922946510972 0.0792114524333 0.017598643469
# long Group Centers
# b
# 0.100128772203 0.171343190963 -0.0781186120601

# %% [markdown]
# <h1 style="text-align:center; color:black;">------------------------------------------------------------------------------</h1>

# %% [markdown]
# ### Demo 3D Plot

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt


def randrange(n, vmin, vmax):
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure(figsize=(16,10))
ax = fig.add_subplot(111, projection='3d')
n = 100
for c, m, zl, zh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zl, zh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
